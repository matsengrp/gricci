# %%
from sage.all import *
load("all-hail-sage/nb-fun.py")
load("graphs.py")
load("code.py")

# %%
g=tetrahedron
nb_show(plot(g))
print ric_unif_rw(g)
# Out:
# Result(coupling={(0, 1): 2/3, (2, 2): 1/12, (0, 0): 1/12, (3, 3): 1/12, (1, 1): 1/12}, W1=2/3, kappa=1/3, ric=4/3)

# %%
g=dodecahedron
nb_show(plot(g))
ricci_list(g,[(0,t) for t in [10,11,12,18,16,11,15]])
# Out:
# [(0, 10, 0),
#  (0, 11, 1/24),
#  (0, 12, 1/18),
#  (0, 18, 1/24),
#  (0, 16, 1/12),
#  (0, 11, 1/24),
#  (0, 15, 1/10)]

# %%
g=icosahedron
nb_show(plot(g))
ricci_list(g,[(0,t) for t in [1,2,3]])
# Out:
# [(0, 1, 1/10), (0, 2, 3/20), (0, 3, 1/6)]

# %%
g=octahedron
nb_show(plot(g))
ricci_list(g,[(0,1),(0,5)])
# Out:
# [(0, 1, 1/4), (0, 5, 1/4)]

# %%
g=R4
nb_show(plot(g))
ricci_list(g,[(0,1)])
# Out:
# [(0, 1, 0)]

# %%
g=R6
nb_show(plot(g))
ricci_list(g,[(0,1)])
# Out:
# [(0, 1, -1/6)]

# %%
g=SnubSquare
nb_show(plot(g))
ricci_list(g,[(0,1)])
# Out:
# [(0, 1, 0)]
